# %% [markdown]
# <a href="https://colab.research.google.com/github/williamfazle/Machine-Learning/blob/main/Hello%2C_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
spam_amount = 0
print(spam_amount)

# Ordering Spam, egg, Spam, Spam, bacon and Spam (4 more servings of Spam)
spam_amount = spam_amount + 4

if spam_amount > 0:
    print("But I don't want ANY spam!")

viking_song = "Spam " * spam_amount
print(viking_song)
# Out:
# 0
# But I don't want ANY spam!
# Spam Spam Spam Spam

# %%
spam_amount = 0

# %%
print(spam_amount)
# Out:
# 0

# %%
# Ordering Spam, egg, Spam, Spam, bacon and Spam (4 more servings of Spam)
spam_amount = spam_amount + 4

# %%
if spam_amount > 0:
    print("But I don't want ANY spam!")

viking_song = "Spam Spam Spam"
print(viking_song)
# Out:
# But I don't want ANY spam!
# Spam Spam Spam

# %%
viking_song = "Spam " * spam_amount
print(viking_song)
# Out:
# Spam Spam Spam Spam

# %%
spam_amount = 0

# %%
type(spam_amount)
# Out:
# int

# %%
type(19.95)
# Out:
# float

# %%
print(5 / 2)
print(6 / 2)
# Out:
# 2.5
# 3.0

# %%
print(5 // 2)
print(6 // 2)
# Out:
# 2
# 3

# %%
8 - 3 + 2
# Out:
# 7

# %%
-3 + 4 * 2
# Out:
# 5

# %%
hat_height_cm = 25
my_height_cm = 190
# How tall am I, in meters, when wearing my hat?
total_height_meters = hat_height_cm + my_height_cm / 100
print("Height in meters =", total_height_meters, "?")
# Out:
# Height in meters = 26.9 ?

# %%
total_height_meters = (hat_height_cm + my_height_cm) / 100
print("Height in meters =", total_height_meters)
# Out:
# Height in meters = 2.15

# %%
print(min(1, 2, 3))
print(max(1, 2, 3))
# Out:
# 1
# 3

# %%
print(abs(32))
print(abs(-32))
# Out:
# 32
# 32

# %%
print(float(10))
print(int(3.33))
# They can even be called on strings!
print(int('807') + 1)
# Out:
# 10.0
# 3
# 808
